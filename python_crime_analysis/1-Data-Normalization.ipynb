# %% [markdown]
# Using Chicago Crime database that is in the form of a 1.8 GB csv file. This file represents one table, and I want to import it into a MySQL DB via the 'Import Data Tool', However, the Data Import currently fails because the formatting of the data is too inconsistent. Therefore, some cleaning and normalization is in order to help make it possible to import first.

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: asttokens==2.4.1 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 1)) (2.4.1)
# Requirement already satisfied: bleach==6.2.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 2)) (6.2.0)
# Requirement already satisfied: bokeh==3.6.1 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 3)) (3.6.1)
# Requirement already satisfied: certifi==2024.8.30 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 4)) (2024.8.30)
# Requirement already satisfied: charset-normalizer==3.4.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 5)) (3.4.0)
# Requirement already satisfied: click==8.1.7 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 6)) (8.1.7)
# Requirement already satisfied: cloudpickle==3.1.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 7)) (3.1.0)
# Requirement already satisfied: colorama==0.4.6 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: colorcet==3.1.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 9)) (3.1.0)
# Requirement already satisfied: comm==0.2.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 10)) (0.2.2)
# Requirement already satisfied: contourpy==1.3.1 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 11)) (1.3.1)
# Requirement already satisfied: dask==2024.11.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 12)) (2024.11.2)
# Requirement already satisfied: debugpy==1.8.9 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 13)) (1.8.9)
# Requirement already satisfied: decorator==5.1.1 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 14)) (5.1.1)
# Requirement already satisfied: executing==2.1.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 15)) (2.1.0)
# Requirement already satisfied: fsspec==2024.10.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 16)) (2024.10.0)
# Requirement already satisfied: greenlet==3.1.1 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 17)) (3.1.1)
# Requirement already satisfied: holoviews==1.20.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 18)) (1.20.0)
# Requirement already satisfied: hvplot==0.11.1 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 19)) (0.11.1)
# Requirement already satisfied: idna==3.10 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 20)) (3.10)
# Requirement already satisfied: ipykernel==6.29.5 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 21)) (6.29.5)
# Requirement already satisfied: ipython==8.29.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 22)) (8.29.0)
# Requirement already satisfied: ipywidgets==8.1.5 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 23)) (8.1.5)
# Requirement already satisfied: jedi==0.19.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 24)) (0.19.2)
# Requirement already satisfied: Jinja2==3.1.4 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 25)) (3.1.4)
# Requirement already satisfied: jupyter_bokeh==4.0.5 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 26)) (4.0.5)
# Requirement already satisfied: jupyter_client==8.6.3 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 27)) (8.6.3)
# Requirement already satisfied: jupyter_core==5.7.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 28)) (5.7.2)
# Requirement already satisfied: jupyterlab_widgets==3.0.13 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 29)) (3.0.13)
# Requirement already satisfied: linkify-it-py==2.0.3 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 30)) (2.0.3)
# Requirement already satisfied: llvmlite==0.43.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 31)) (0.43.0)
# Requirement already satisfied: locket==1.0.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 32)) (1.0.0)
# Requirement already satisfied: Markdown==3.7 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 33)) (3.7)
# Requirement already satisfied: markdown-it-py==3.0.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 34)) (3.0.0)
# Requirement already satisfied: MarkupSafe==3.0.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 35)) (3.0.2)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 36)) (0.1.7)
# Requirement already satisfied: mdit-py-plugins==0.4.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 37)) (0.4.2)
# Requirement already satisfied: mdurl==0.1.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 38)) (0.1.2)
# Requirement already satisfied: multipledispatch==1.0.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 39)) (1.0.0)
# Requirement already satisfied: mypysql==0.1.7 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 40)) (0.1.7)
# Requirement already satisfied: mysql-connector-python==9.1.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 41)) (9.1.0)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 42)) (1.6.0)
# Requirement already satisfied: numba==0.60.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 43)) (0.60.0)
# Requirement already satisfied: numpy==2.0.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 44)) (2.0.2)
# Requirement already satisfied: packaging==24.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 45)) (24.2)
# Requirement already satisfied: pandas==2.2.3 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 46)) (2.2.3)
# Requirement already satisfied: panel==1.5.4 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 47)) (1.5.4)
# Requirement already satisfied: param==2.1.1 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 48)) (2.1.1)
# Requirement already satisfied: parso==0.8.4 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 49)) (0.8.4)
# Requirement already satisfied: partd==1.4.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 50)) (1.4.2)
# Requirement already satisfied: pillow==11.0.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 51)) (11.0.0)
# Requirement already satisfied: platformdirs==4.3.6 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 52)) (4.3.6)
# Requirement already satisfied: prompt_toolkit==3.0.48 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 53)) (3.0.48)
# Requirement already satisfied: psutil==6.1.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 54)) (6.1.0)
# Requirement already satisfied: pure_eval==0.2.3 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 55)) (0.2.3)
# Requirement already satisfied: pyct==0.5.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 56)) (0.5.0)
# Requirement already satisfied: Pygments==2.18.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 57)) (2.18.0)
# Requirement already satisfied: PyMySQL==1.1.1 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 58)) (1.1.1)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 59)) (2.9.0.post0)
# Requirement already satisfied: pytz==2024.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 60)) (2024.2)
# Requirement already satisfied: pyviz_comms==3.0.3 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 61)) (3.0.3)
# Requirement already satisfied: pywin32==308 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 62)) (308)
# Requirement already satisfied: PyYAML==6.0.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 63)) (6.0.2)
# Requirement already satisfied: pyzmq==26.2.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 64)) (26.2.0)
# Requirement already satisfied: requests==2.32.3 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 65)) (2.32.3)
# Requirement already satisfied: scipy==1.14.1 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 66)) (1.14.1)
# Requirement already satisfied: six==1.16.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 67)) (1.16.0)
# Requirement already satisfied: SQLAlchemy==2.0.36 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 68)) (2.0.36)
# Requirement already satisfied: stack-data==0.6.3 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 69)) (0.6.3)
# Requirement already satisfied: toolz==1.0.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 70)) (1.0.0)
# Requirement already satisfied: tornado==6.4.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 71)) (6.4.2)
# Requirement already satisfied: tqdm==4.67.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 72)) (4.67.0)
# Requirement already satisfied: traitlets==5.14.3 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 73)) (5.14.3)
# Requirement already satisfied: typing_extensions==4.12.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 74)) (4.12.2)
# Requirement already satisfied: tzdata==2024.2 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 75)) (2024.2)
# Requirement already satisfied: uc-micro-py==1.0.3 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 76)) (1.0.3)
# Requirement already satisfied: Unidecode==1.3.8 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 77)) (1.3.8)
# Requirement already satisfied: urllib3==2.2.3 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 78)) (2.2.3)
# Requirement already satisfied: wcwidth==0.2.13 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 79)) (0.2.13)
# Requirement already satisfied: webencodings==0.5.1 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 80)) (0.5.1)
# Requirement already satisfied: widgetsnbextension==4.0.13 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 81)) (4.0.13)
# Requirement already satisfied: xarray==2024.11.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 82)) (2024.11.0)
# Requirement already satisfied: xyzservices==2024.9.0 in c:\repos\luke_m_work_portfolio\python_crime_analysis\.venv\lib\site-packages (from -r requirements.txt (line 83)) (2024.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import pandas as pd
import datetime as datetime

# %% [markdown]
# To set up for later steps, I'm going to pull out all of the column names present in the Chicago DB Crimes .csv file.

# %%
def get_column_names(input_file):
    """
    Extracts column names from the header of a CSV file.

    Parameters:
    - input_file (str): Path to the CSV file.

    Returns:
    - list: A list of column names.
    """
    with open(input_file, mode='r', encoding='utf-8') as infile:
        reader = csv.reader(infile)
        header = next(reader, None)  # Read the first row as the header
        if header:
            return [col.strip() for col in header]  # Remove any extra spaces
        else:
            raise ValueError("The CSV file does not contain a header row.")

# Replace with your file path
input_csv = 'Crimes_-_2001_to_Present.csv'

try:
    column_names = get_column_names(input_csv)
    print("Column names in the CSV file:")
    print(column_names)
except Exception as e:
    print(f"Error: {e}")
# Out:
# Column names in the CSV file:
# ['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type', 'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate', 'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude', 'Location']

# %% [markdown]
# When attempting to import data via the Import Data Tool in DBeaver (Open Source Universal DB Tool), I found that some rows that had a boolean values wheren't consistent, so here I'm trying to find every value thats 'bad' so I know what I need to find and replace.

# %%
def find_unique_values(input_file, target_column):
    """
    Reads a CSV file and collects all unique values in the specified column.

    Parameters:
    - input_file (str): Path to the CSV file.
    - target_column (str): Name of the column to analyze.

    Returns:
    - set: A set of unique values found in the specified column.
    """
    unique_values = set()

    with open(input_file, mode='r', encoding='utf-8') as infile:
        reader = csv.DictReader(infile)
        
        if target_column not in reader.fieldnames:
            raise ValueError(f"Column '{target_column}' not found in the CSV file.")
        
        for row in reader:
            value = row.get(target_column, None)
            if value is not None:
                unique_values.add(value.strip())

    return unique_values

# Replace with your file path and column name
input_csv = 'Crimes_-_2001_to_Present.csv'
column_names = ['Arrest', 'Domestic', 'Beat', 'District', 'Ward', 'Community Area']

#try:
#    for i in column_names:
        #unique_values = find_unique_values(input_csv, i)
        #print(f"Unique values found in column '{i}':")
        #for value in unique_values:
        #    print(value)
#except Exception as e:
#    print(f"Error: {e}")

# %% [markdown]
# Import some constants to help navigate the DB.
#
# Also spinning up MySQL and SQLalchemy Connections to be used later.
#
# This is the Query I executed in DBeaver in order to create the Table:
# ```SQL
# USE chicagocrime;
#
# CREATE TABLE IF NOT EXISTS crime_records (
#     id INT PRIMARY KEY,
#     case_number VARCHAR(50),
#     date DATETIME,
#     block TEXT,
#     iucr VARCHAR(10),
#     primary_type TEXT,
#     description TEXT,
#     location_description TEXT,
#     arrest BOOLEAN,
#     domestic BOOLEAN,
#     beat VARCHAR(10),
#     district VARCHAR(10),
#     ward INT,
#     community_area VARCHAR(50),
#     fbi_code VARCHAR(10),
#     x_coordinate DOUBLE,
#     y_coordinate DOUBLE,
#     year INT,
#     updated_on DATETIME,
#     latitude DOUBLE,
#     longitude DOUBLE,
#     location TEXT
# )
# ```

# %%
from CC_DB_Constants import CC_DB_TABLE_DEFINTIONS, DB_USR_CONFIG, TABLE_NAMES, DB_COLUMN_NAME_MAP

import mysql.connector
import mysql.connector.errorcode
from sqlalchemy import create_engine
import pymysql

con_string = f"mysql+pymysql://{DB_USR_CONFIG['user']}:{DB_USR_CONFIG['password']}@{DB_USR_CONFIG['host']}/{DB_USR_CONFIG['database']}"

# %% [markdown]
# Load the Crime Records as a Pandas Dataframe, preform some data cleaning and formatting the data to match what MySQL wants, and then Insert all of the data and commit it to the MySQL DB.

# %%
def convert_to_iso_format(date_str):
    """
    Converts a date string in the format 'MM/DD/YYYY HH:MM:SS AM/PM'
    into ISO 8601 format 'YYYY-MM-DD HH:MM:SS'.
    """
    # Define the input format
    input_format = '%m/%d/%Y %I:%M:%S %p'
    # Define the desired output format
    output_format = '%Y-%m-%d %H:%M:%S'
    
    try:
        # Parse the input string into a datetime object
        datetime_obj = datetime.datetime.strptime(date_str, input_format)
        # Format the datetime object into the ISO format
        iso_formatted_date = datetime_obj.strftime(output_format)
        return iso_formatted_date
    except ValueError as e:
        print(f"Error converting date: {e}")
        return None


def cast_value(value, expected_type):
    """
    Attempts to cast a value to the expected type.
    Returns the casted value if successful, or None if casting fails.
    """
    try:
        if expected_type == bool:
            # Special handling for boolean values
            if str(value).lower() in ("true", "1", "yes"):
                return '1' # equivalent to 'true'
            elif str(value).lower() in ("false", "0", "no"):
                return '0' # equivalent to 'false'
            else:
                raise ValueError(f"Cannot cast {value} to bool.")
        elif expected_type == datetime.datetime:
            # Attempt to parse datetime
            return convert_to_iso_format(value)
        elif expected_type == int and value == "":
            # Allow empty strings to be cast to None for integers
            return None
        elif expected_type == float and value == "":
            # Allow empty strings to be cast to None for floats
            return None
        elif value in ("", "N/A", "NULL"):
            return None
        else:
            # General casting
            return expected_type(value)
    except (ValueError, TypeError):
        return None

# Main function to process and insert data
def clean_and_insert_pandas(input_file, table_name):
    # Load the CSV into a Pandas DataFrame
    df = pd.read_csv(input_file)

    df.rename(columns=DB_COLUMN_NAME_MAP[table_name], inplace=True)
    print(f"Columns renamed to: {df.columns}")
    
    # Apply data cleaning and transformations
    for column, config in CC_DB_TABLE_DEFINTIONS[table_name].items():
        if column in df.columns:
            expected_type = config['python_type']
            if expected_type == bool:
                df[column] = df[column].apply(lambda x: str(x).lower() in ("true", "1", "yes"))
                df[column] = df[column].apply(lambda x: str(x).lower() in ("false", "0", "no"))
            elif expected_type == datetime.datetime:
                df[column] = df[column].apply(lambda x: convert_to_iso_format(x) if pd.notna(x) else None)
            elif expected_type in [int, float]:
                df[column] = pd.to_numeric(df[column], errors='coerce')
            else:
                #df[column] = df[column].fillna(None)
                print(f"Unhandled expected type encountered: {expected_type}")

    # Create SQLAlchemy engine
    engine = create_engine(con_string)

    # Insert data into the database
    try:
        df.to_sql(TABLE_NAMES['crime'], con=engine, if_exists='append', index=False, chunksize=10000)
        print("Data inserted successfully!")
    except Exception as e:
        print(f"Error inserting data: {e}")

# Replace these with your file path and table name
input_csv = 'Crimes_-_2001_to_Present.csv'
table_name = 'crime_records'

clean_and_insert_pandas(input_csv, table_name)
# Out:
# Columns renamed to: Index(['id', 'case_number', 'date', 'block', 'iucr', 'primary_type',
#        'description', 'location_description', 'arrest', 'domestic', 'beat',
#        'district', 'ward', 'community_area', 'fbi_code', 'x_coordinate',
#        'y_coordinate', 'year', 'updated_on', 'latitude', 'longitude',
#        'location'],
#       dtype='object')
# Unhandled expected type encountered: <class 'str'>
# Unhandled expected type encountered: <class 'str'>
# Unhandled expected type encountered: <class 'str'>
# Unhandled expected type encountered: <class 'str'>
# Unhandled expected type encountered: <class 'str'>
# Unhandled expected type encountered: <class 'str'>
# Unhandled expected type encountered: <class 'str'>
# Unhandled expected type encountered: <class 'str'>
# Unhandled expected type encountered: <class 'str'>
# Unhandled expected type encountered: <class 'str'>
# Unhandled expected type encountered: <class 'str'>
# Data inserted successfully!
